# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print(x_train.shape, x_test.shape)
x_train = x_train / x_train.max()
x_test = x_test / x_test.max()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# (60000, 28, 28) (10000, 28, 28)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax'),
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_4 (Dense)             (None, 256)               200960
#
#  dense_5 (Dense)             (None, 64)                16448
#
#  dense_6 (Dense)             (None, 32)                2080
#
#  dense_7 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 219,818
# Trainable params: 219,818
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train,
          validation_data=(x_test, y_test),
          epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2336 - accuracy: 0.9309 - val_loss: 0.1185 - val_accuracy: 0.9618
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0971 - accuracy: 0.9708 - val_loss: 0.0937 - val_accuracy: 0.9700
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0688 - accuracy: 0.9785 - val_loss: 0.1035 - val_accuracy: 0.9692
# Epoch 4/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0516 - accuracy: 0.9836 - val_loss: 0.0869 - val_accuracy: 0.9735
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0411 - accuracy: 0.9861 - val_loss: 0.0791 - val_accuracy: 0.9774
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0342 - accuracy: 0.9882 - val_loss: 0.0834 - val_accuracy: 0.9774
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0277 - accuracy: 0.9907 - val_loss: 0.0973 - val_accuracy: 0.9740
# Epoch 8/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0252 - accuracy: 0.9919 - val_loss: 0.0851 - val_accuracy: 0.9773
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0233 - accuracy: 0.9925 - val_loss: 0.0914 - val_accuracy: 0.9789
# Epoch 10/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0205 - accuracy: 0.9930 - val_loss: 0.0753 - val_accuracy: 0.9816

# %%
# 모델 저장
model.save('h5-model.h5')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_4 (Dense)             (None, 256)               200960
#
#  dense_5 (Dense)             (None, 64)                16448
#
#  dense_6 (Dense)             (None, 32)                2080
#
#  dense_7 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 219,818
# Trainable params: 219,818
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 저장된 모델 불러오기
load_model = tf.keras.models.load_model('h5-model.h5')

# %%
load_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_4 (Dense)             (None, 256)               200960
#
#  dense_5 (Dense)             (None, 64)                16448
#
#  dense_6 (Dense)             (None, 32)                2080
#
#  dense_7 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 219,818
# Trainable params: 219,818
# Non-trainable params: 0
# _________________________________________________________________

# %%
load_model.get_weights()[0]
# Out:
# array([[ 0.07129641,  0.06201237, -0.07172326, ..., -0.03439374,
#         -0.00780763, -0.03072358],
#        [ 0.06202742,  0.00945162,  0.0337744 , ..., -0.03389303,
#          0.03807019,  0.00649441],
#        [ 0.07320946, -0.0114869 , -0.03266612, ...,  0.0232156 ,
#         -0.01266462, -0.01130424],
#        ...,
#        [ 0.01658592,  0.02308714,  0.02550897, ...,  0.04980712,
#          0.05395713,  0.04276605],
#        [ 0.02261382,  0.04779421, -0.06359854, ...,  0.03720777,
#         -0.02210062, -0.02211091],
#        [ 0.0698396 ,  0.01587352,  0.02740294, ...,  0.07153915,
#          0.02239624,  0.02497237]], dtype=float32)

# %%
model.get_weights()[0]
# Out:
# array([[ 0.07129641,  0.06201237, -0.07172326, ..., -0.03439374,
#         -0.00780763, -0.03072358],
#        [ 0.06202742,  0.00945162,  0.0337744 , ..., -0.03389303,
#          0.03807019,  0.00649441],
#        [ 0.07320946, -0.0114869 , -0.03266612, ...,  0.0232156 ,
#         -0.01266462, -0.01130424],
#        ...,
#        [ 0.01658592,  0.02308714,  0.02550897, ...,  0.04980712,
#          0.05395713,  0.04276605],
#        [ 0.02261382,  0.04779421, -0.06359854, ...,  0.03720777,
#         -0.02210062, -0.02211091],
#        [ 0.0698396 ,  0.01587352,  0.02740294, ...,  0.07153915,
#          0.02239624,  0.02497237]], dtype=float32)

# %%
model.save('saved_model')

# %%
saved_model = tf.keras.models.load_model('saved_model')

# %%
saved_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_4 (Dense)             (None, 256)               200960
#
#  dense_5 (Dense)             (None, 64)                16448
#
#  dense_6 (Dense)             (None, 32)                2080
#
#  dense_7 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 219,818
# Trainable params: 219,818
# Non-trainable params: 0
# _________________________________________________________________
